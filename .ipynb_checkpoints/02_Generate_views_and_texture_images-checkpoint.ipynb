# %% [markdown]
# ## Load the metadata
#
# The metadata pre-processed in notebook 1 contains the id's of the 3D-models that will be downloaded.

# %%
import pandas as pd
import os

# reload the cleaned-up data
metadata_df = pd.read_csv(os.path.join('data', 'metadata.csv'), index_col=False)
print('There are {} 3D-models in the dataset.'.format(metadata_df.shape[0]))
# Out:
# There are 970 3D-models in the dataset.

# %% [markdown]
# ## Downloading 3D models
# I obtained 3D-models from the [Sketchfab website](https://sketchfab.com/3d-models/categories/cultural-heritage-history?date=week&features=downloadable&licenses=322a749bcfa841b29dff1e8a1bb74b0b&licenses=b9ddc40b93e34cdca1fc152f39b9f375&licenses=72360ff1740d419791934298b8b6d270&licenses=bbfe3f7dbcdd4122b966b85b9786a989&licenses=2628dbe5140a4e9592126c8df566c0b7&licenses=34b725081a6a4184957efaec2cb84ed3&licenses=7c23a1ba438d4306920229c12afcb5f9&licenses=783b685da9bf457d81e829fa283f3567&licenses=5b54cf13b1a4422ca439696eb152070d&sort_by=-likeCount). Sketchfab provides an [API](https://docs.sketchfab.com/data-api/v3/index.html#!/models/get_v3_models_uid_download) for querying and downloading 3D-models. I contacted Sketchfab to check if it would be alright to download a large number of 3D-models. They have been very supportive to my idea and I managed to use the API to download all the metadata and a few 3D-models.
# The API requires a Sketchfab account and a key. The key is stored in the file `client_credentials.json` (not included in the submission). Please note that:
# * 3D-models are large files. The project should require an estimated 20 GB of data, for the downloaded files alone. I setup a virtual storage with 50 GB to hold the data for this project. Github recommends keeping projects under 5 GB. Therefore I will not be able to upload the 3D-models as such to the capstone repository, but only the pre-processed files.
# * the Sketchfab API has various download rate restrictions (per day, per hour, per minute), so that the download process has to be extended over a period of several days.

# %%
import json
import requests
import os
import time

# load credentials stored in local file
with open('client_credentials.json') as file:
    client_credentials = json.load(file)
API_TOKEN = client_credentials['api_token'] # Token from Sketchfab account

DOWNLOAD_DIR = '/mnt/Disk2/downloaded_models' # Folder to store the downloaded files
DOWNLOAD_DELAY = 20 # seconds, 200 / hour API rate limit
DOWNLOAD_ENDPOINT = 'https://api.sketchfab.com/v3/models/{}/download' # API endpoint

# HTTP request headers
headers = {'Authorization': 'Token {}'.format(API_TOKEN)} # Authorization method used
headers.update({'Content-Type': 'application/json'}) # http content type of the request

def download_data(uid):
    """
    Downloads a 3D-model from Sketchfab, saves it to a zipped file.
    @param: uid unique id of the model
    @raises: RequestException, e.g. API limit exceeded
    """
    # get the download url of the model
    # this url is only valid for a few minutes
    r = requests.get(
        DOWNLOAD_ENDPOINT.format(model_uid),
        headers = headers
    )
    r.raise_for_status() # throw exception if request status is not OK
    model_link = json.loads(r.text)
    url = model_link['gltf']['url'] # download url of the model

    # download the 3D-model, save it to file
    r = requests.get(url)
    with open(filename,'wb') as output_file:
        output_file.write(r.content)
            

try:
    # loop through the metadata table and download each 3D-model
    total = len(metadata_df)
    counter = 1
    for model_uid in metadata_df['id']:
        filename = os.path.join(DOWNLOAD_DIR, '{}.zip'.format(model_uid)) # file to save the 3D-model
        if os.path.isfile(filename): # check that the file hasn't been downloaded already
            print('File {} already exists'.format(filename))
        else:
            print('Downloading model {} ({}/{})'.format(model_uid, counter, total))
            download_data(model_uid) # download and save the 3D-model
            time.sleep(DOWNLOAD_DELAY) # don't hit the API too hard
        counter += 1

# Downloads may fail, typically when API limit exceeded
except requests.exceptions.RequestException:
    print('Download failed for 3D-model: {}'.format(model_uid))
# Out:
# File /mnt/Disk2/downloaded_models/a049baa005da476bb7ffe1df5e6b4f78.zip already exists
# File /mnt/Disk2/downloaded_models/836630c9eb6344878f5b3e72aaa37f8b.zip already exists
# File /mnt/Disk2/downloaded_models/77d11d8ec01e424e829b9914c388b0a1.zip already exists
# File /mnt/Disk2/downloaded_models/c9c8bce4d27a4fef88622682bf2741b1.zip already exists
# File /mnt/Disk2/downloaded_models/991d3fd5aab643609819ade2a1df1eb2.zip already exists
# File /mnt/Disk2/downloaded_models/89fdc50c378c4b8ea4348f673318a179.zip already exists
# File /mnt/Disk2/downloaded_models/f5a96c73c0eb49a1b787ae258eb02891.zip already exists
# File /mnt/Disk2/downloaded_models/ab333c7e6d0f41cbafbbc36b634488a5.zip already exists
# File /mnt/Disk2/downloaded_models/fbe2776af5f44d83bb32e6633d151178.zip already exists
# File /mnt/Disk2/downloaded_models/72aba513c29241a3a0843a14dba596a5.zip already exists
# File /mnt/Disk2/downloaded_models/7bbe7a566f074896b9cffea1e353275a.zip already exists
# File /mnt/Disk2/downloaded_models/036abe36af224e588d3f573f44c24ab3.zip already exists
# File /mnt/Disk2/downloaded_models/3af9453ca5694a3aae66a05f27d94881.zip already exists
# File /mnt/Disk2/downloaded_models/c7c762e635ab4403b7363860665009ac.zip already exists
# File /mnt/Disk2/downloaded_models/07ad36c0658e4eafa91f0137e49fad58.zip already exists
# File /mnt/Disk2/downloaded_models/5cd861450b544fccb7ac3ecf525afadd.zip already exists
# File /mnt/Disk2/downloaded_models/c5374274b68e4d338880f6d7ac79e062.zip already exists
# File /mnt/Disk2/downloaded_models/d9fa455509ea4bc4b9acde9b7d20df14.zip already exists
# File /mnt/Disk2/downloaded_models/ec08a45c7aa74ed4945827c47912b0c4.zip already exists
# File /mnt/Disk2/downloaded_models/bc99f1acf7764a91ba6800864c6124c2.zip already exists
# File /mnt/Disk2/downloaded_models/5e39b7649dc4456e9b911059a3c4c0ba.zip already exists
# File /mnt/Disk2/downloaded_models/ccdf0d3aabe6468493c5b87e29a10bef.zip already exists
# File /mnt/Disk2/downloaded_models/903905eb713245efbf1769456822fa5c.zip already exists
# File /mnt/Disk2/downloaded_models/bfae6fa9a7f64b9eb16f57c05553c612.zip already exists
# File /mnt/Disk2/downloaded_models/2cf72e290a2e4849841df9d29905911e.zip already exists
# File /mnt/Disk2/downloaded_models/4dd0239e30844be5a9dffdcde2bde844.zip already exists
# File /mnt/Disk2/downloaded_models/74b5c985f7a747fe9863f3b5f977a056.zip already exists
# File /mnt/Disk2/downloaded_models/1661929dfcbf4a829b8f81512a767f92.zip already exists
# File /mnt/Disk2/downloaded_models/663fd55d530c4f1abeefb92b7be45502.zip already exists
# File /mnt/Disk2/downloaded_models/09b62c5be969464a99a58eb5160e3122.zip already exists
# File /mnt/Disk2/downloaded_models/5c5c3b9ae7874b709c10ac57dad33195.zip already exists
# File /mnt/Disk2/downloaded_models/fa6cfc147c1c44ccb014e5c29cde27c9.zip already exists
# File /mnt/Disk2/downloaded_models/87e986b6a3784421a82b86f9a0977183.zip already exists
# File /mnt/Disk2/downloaded_models/826eeb384b644d278e78c802ac59fbc3.zip already exists
# File /mnt/Disk2/downloaded_models/ad1c9d8e81b04e13bf4220675337f04f.zip already exists
# File /mnt/Disk2/downloaded_models/7d3689df8ca74f97a0bd70c3bc8f7619.zip already exists
# File /mnt/Disk2/downloaded_models/c65c0fae7d0e4bbca21839fb00dabb0f.zip already exists
# File /mnt/Disk2/downloaded_models/e2aba8bd92fb4247913614058408e4e8.zip already exists
# File /mnt/Disk2/downloaded_models/7c2fde254a1741a6b2b99d8d2adcfd1c.zip already exists
# File /mnt/Disk2/downloaded_models/40c79ef7dc9c466da86c44851103dee5.zip already exists
# File /mnt/Disk2/downloaded_models/e2ce3cedb2d144508564661251dff30c.zip already exists
# File /mnt/Disk2/downloaded_models/0a17eb9617f04a7bab8fc04c57f2391f.zip already exists
# File /mnt/Disk2/downloaded_models/7ea7613e42b044e8bf80af283401a775.zip already exists
# File /mnt/Disk2/downloaded_models/af5d21db39474e568712858ee69365d2.zip already exists
# File /mnt/Disk2/downloaded_models/620b812307624ef08c32720b068b0bed.zip already exists
# File /mnt/Disk2/downloaded_models/e747b293687d432fa0604cf4473a6130.zip already exists
# File /mnt/Disk2/downloaded_models/66d7fc023fcd4e38870fe3599a218454.zip already exists
# File /mnt/Disk2/downloaded_models/281cd05065a9453ab110fd14219472ae.zip already exists
# File /mnt/Disk2/downloaded_models/9d35c551ba634408a3178554dde9db6d.zip already exists
# File /mnt/Disk2/downloaded_models/842045cfa6a04652a207aeea174c236d.zip already exists
# File /mnt/Disk2/downloaded_models/2fcf10ea5ab84a919f153a2ccc6c104c.zip already exists
# File /mnt/Disk2/downloaded_models/d5a49ae5fb044aceb74a79a026e299d1.zip already exists
# File /mnt/Disk2/downloaded_models/97c96e278ffc4da394d65151156018e0.zip already exists
# File /mnt/Disk2/downloaded_models/844e310df5c3443cac8c89258edc7420.zip already exists
# File /mnt/Disk2/downloaded_models/7b8960be837445b288627f82e7d2883e.zip already exists
# File /mnt/Disk2/downloaded_models/50bf63cd76f749e18716013ba18c7b2e.zip already exists
# File /mnt/Disk2/downloaded_models/14349bdc28524152bfb8ac955875ffee.zip already exists
# File /mnt/Disk2/downloaded_models/88fa6b0f57c7435f95a8ced0f2754db7.zip already exists
# File /mnt/Disk2/downloaded_models/82a8c50900714a6e9a479603b729e745.zip already exists
# File /mnt/Disk2/downloaded_models/1021e67cf82b48e2bd773f55605d858f.zip already exists
# File /mnt/Disk2/downloaded_models/786b42dd265e4a978d982403f8d99a28.zip already exists
# File /mnt/Disk2/downloaded_models/7f4747bf4d0a4368aa257c1c76ecba48.zip already exists
# File /mnt/Disk2/downloaded_models/aef71cd859c44af8b45bbfc668fc22fd.zip already exists
# File /mnt/Disk2/downloaded_models/0580c3a43e55483fb154d70d1ea42973.zip already exists
# File /mnt/Disk2/downloaded_models/6eed06fca0d94de984c356fa912bf336.zip already exists
# File /mnt/Disk2/downloaded_models/9ce77031ac2d4072bba9f0f984f841df.zip already exists
# File /mnt/Disk2/downloaded_models/fef04f8c85184135b5cf692849476444.zip already exists
# File /mnt/Disk2/downloaded_models/3b2ca38b8ef94357a47a9b02d3007435.zip already exists
# File /mnt/Disk2/downloaded_models/8f73cee69ad34b98addf6915413d4f5e.zip already exists
# File /mnt/Disk2/downloaded_models/0be4abc5aef7421c9998ed98e8942874.zip already exists
# File /mnt/Disk2/downloaded_models/58e99668cfd84861bc5069a991f575af.zip already exists
# File /mnt/Disk2/downloaded_models/9bc09a8f9a9c4d64981bb8255f18fbf8.zip already exists
# File /mnt/Disk2/downloaded_models/4557680b99ba444c9217aaad943a61b7.zip already exists
# File /mnt/Disk2/downloaded_models/16359d2015de45728fc617365427ab43.zip already exists
# File /mnt/Disk2/downloaded_models/e34131dfedb34648bf0c928f9c2dc765.zip already exists
# File /mnt/Disk2/downloaded_models/76f76b249f3743ec9419119b5aef46b9.zip already exists
# File /mnt/Disk2/downloaded_models/cbca2d8dcbd846bebeed4fc6c4160eca.zip already exists
# File /mnt/Disk2/downloaded_models/4b9e16d8c9c84bc08a0c1139785f6fa7.zip already exists
# File /mnt/Disk2/downloaded_models/5dae25e4bb844ebdb4e632e636c8d2d3.zip already exists
# File /mnt/Disk2/downloaded_models/e94d945b24034aa0ab9f968155bb6f76.zip already exists
# File /mnt/Disk2/downloaded_models/0fed33f3416747f6a022f1a5c6313c1e.zip already exists
# File /mnt/Disk2/downloaded_models/f8b3d867de194e6cb587c89d54ed8f0e.zip already exists
# File /mnt/Disk2/downloaded_models/255ea8cbb5714602a0fa30582b4d5c37.zip already exists
# File /mnt/Disk2/downloaded_models/d83ac6b3a15b48f19e5c32fd4134435f.zip already exists
# File /mnt/Disk2/downloaded_models/ecd6818cca54428cba27ec922eec1f58.zip already exists
# File /mnt/Disk2/downloaded_models/713098ad352840ad847236d6a3d1ce0d.zip already exists
# File /mnt/Disk2/downloaded_models/415b4b4dad844ac9a9023ce0d1cb161b.zip already exists
# File /mnt/Disk2/downloaded_models/35b0807808b94aac8ff98adf5945ba4b.zip already exists
# File /mnt/Disk2/downloaded_models/784a7ca4a0674bce8ec62cc1f61f2490.zip already exists
# File /mnt/Disk2/downloaded_models/f87db4ec91bc4ea4a9a95a5ca1eef66b.zip already exists
# File /mnt/Disk2/downloaded_models/32163b59856143428294cdfd027a0cd0.zip already exists
# File /mnt/Disk2/downloaded_models/22d83d2009544bb3b3ed7cedfbe60a18.zip already exists
# File /mnt/Disk2/downloaded_models/c7df0f7671d34fb9817d37067072f9ab.zip already exists
# File /mnt/Disk2/downloaded_models/27acee6817774e3cb2cb2cd50e0a374a.zip already exists
# File /mnt/Disk2/downloaded_models/b2231d7c008140d5a6ff59adfdf564d2.zip already exists
# File /mnt/Disk2/downloaded_models/8fbc614adc794ddbbf7a44f351c94653.zip already exists
# File /mnt/Disk2/downloaded_models/3cc73d209f1649f49bb6c088ad121608.zip already exists
# File /mnt/Disk2/downloaded_models/36e5d690f07f4487b2715dd2fb4026db.zip already exists
# File /mnt/Disk2/downloaded_models/5de591d9e5d84e90a838fc411fdab963.zip already exists
# File /mnt/Disk2/downloaded_models/793ca9f23c8e462eb8bd89c697b4a1ae.zip already exists
# File /mnt/Disk2/downloaded_models/dcccfdc3954d42eb8565ed651b8929bb.zip already exists
# File /mnt/Disk2/downloaded_models/fca9c0e7606847d6939f949b10f3afa5.zip already exists
# File /mnt/Disk2/downloaded_models/32488a5c8b6146c4a94f98cefeb718b8.zip already exists
# File /mnt/Disk2/downloaded_models/76207fc6c5d640df8483d256558b580f.zip already exists
# File /mnt/Disk2/downloaded_models/cd87765b340d423887abfdf29ad11b32.zip already exists
# File /mnt/Disk2/downloaded_models/8145be70002b485ab040bc3b31244b43.zip already exists
# File /mnt/Disk2/downloaded_models/5db30cd2846e49fc9b9670ec5e42d7b6.zip already exists
# File /mnt/Disk2/downloaded_models/cf7a8ab10c4f4cb28e77d4866cfce11a.zip already exists
# File /mnt/Disk2/downloaded_models/65e992e1326c4615bdada49b02005e16.zip already exists
# File /mnt/Disk2/downloaded_models/9d352da0bc764b79a118c6a53aee4599.zip already exists
# File /mnt/Disk2/downloaded_models/290e5dbef39f4dd289c93a2af4cd4ff2.zip already exists
# File /mnt/Disk2/downloaded_models/00448ec0c83b4538a85a8b783f72dd98.zip already exists
# File /mnt/Disk2/downloaded_models/7d2737e16fcf4d40bc549521ba6a2d02.zip already exists
# File /mnt/Disk2/downloaded_models/c02fe83990f24260b3bfc4b0f9bb74d9.zip already exists
# File /mnt/Disk2/downloaded_models/cc4ae96b60524530b1f4d7728366cdeb.zip already exists
# File /mnt/Disk2/downloaded_models/faf5e9d775a340019603d5868b77ef1b.zip already exists
# File /mnt/Disk2/downloaded_models/7e9e5cb85b534a70a6371b9b1ca8fcb1.zip already exists
# File /mnt/Disk2/downloaded_models/4f58ca0df18c42b59d5d761891b768d4.zip already exists
# File /mnt/Disk2/downloaded_models/b12fcb929ee043dcb0770ef32012d7d6.zip already exists
# File /mnt/Disk2/downloaded_models/b4371e6cd06746ae99da2723488a1428.zip already exists
# File /mnt/Disk2/downloaded_models/295f55cfc08f4252955bafbe15a67a4b.zip already exists
# File /mnt/Disk2/downloaded_models/6e0fbf15ee104d888fa32411c768cd34.zip already exists
# File /mnt/Disk2/downloaded_models/9eb9c1f2c2ea4c5ba9e5e04ac7e636ac.zip already exists
# File /mnt/Disk2/downloaded_models/9d815a629846462a8107baf936ee4e66.zip already exists
# File /mnt/Disk2/downloaded_models/7adfc1c94f4c483fb2337620e5fe0f79.zip already exists
# File /mnt/Disk2/downloaded_models/48204b04075b4295adda55a913fe9b3f.zip already exists
# File /mnt/Disk2/downloaded_models/a2ef1e945e8a4d5b9b6425c96083a3b7.zip already exists
# File /mnt/Disk2/downloaded_models/e3eb88143d0b4e039bf7a21fdac2e4b1.zip already exists
# File /mnt/Disk2/downloaded_models/a5fc673f17c947bebd3c44ee181cabc4.zip already exists
# File /mnt/Disk2/downloaded_models/b4f97bfa98234ac58b2991d6ac0a18a9.zip already exists
# File /mnt/Disk2/downloaded_models/795ffc209ab840f79395239a619a332d.zip already exists
# File /mnt/Disk2/downloaded_models/8b16dc8f657f4132a4e150c85cb04c2a.zip already exists
# File /mnt/Disk2/downloaded_models/6d38fa5f96d64b158f3f0fa11187bdf7.zip already exists
# File /mnt/Disk2/downloaded_models/dcf2a90be4934800b8ee316723a9ff4c.zip already exists
# File /mnt/Disk2/downloaded_models/e06bceb2b62f444794a5d8030ab70ecd.zip already exists
# File /mnt/Disk2/downloaded_models/498cc597ea26402dab17dcf405a82ce6.zip already exists
# File /mnt/Disk2/downloaded_models/e4f4f433c23b4b028dbd01536759d522.zip already exists
# File /mnt/Disk2/downloaded_models/fdb2cbc1bfa44013ad92447663220efe.zip already exists
# File /mnt/Disk2/downloaded_models/8d16343b2f4b4184b57a86793ea3b97d.zip already exists
# File /mnt/Disk2/downloaded_models/221e2fc888b04bc587aabcb709159e60.zip already exists
# File /mnt/Disk2/downloaded_models/9605b2b278774b5bb4e486695e6d920a.zip already exists
# File /mnt/Disk2/downloaded_models/421a6e8ef6644c6880ace887c9dbfdd9.zip already exists
# File /mnt/Disk2/downloaded_models/7cc25b8ed0374a0592df7968fa1f0087.zip already exists
# File /mnt/Disk2/downloaded_models/3a8bfbb543904e95b70f97d5c0a3b125.zip already exists
# File /mnt/Disk2/downloaded_models/3a8bfbb543904e95b70f97d5c0a3b125.zip already exists
# File /mnt/Disk2/downloaded_models/889d114ac498488bb074e67bd6e9165e.zip already exists
# File /mnt/Disk2/downloaded_models/be690360e1e944bf994f742de184c655.zip already exists
# File /mnt/Disk2/downloaded_models/5ae37b4d106f47b2befe24634fe2bbe0.zip already exists
# File /mnt/Disk2/downloaded_models/4774474760bf4aad80568195d6f2c63e.zip already exists
# File /mnt/Disk2/downloaded_models/1a50b0867873481681109c8f924df0a3.zip already exists
# File /mnt/Disk2/downloaded_models/93e565159eba4985ab50c53bfc90a9f5.zip already exists
# File /mnt/Disk2/downloaded_models/2f132a824bdf4ad1be432fb036243e49.zip already exists
# File /mnt/Disk2/downloaded_models/c1c0a8fbb8304502b79e31b2224daf01.zip already exists
# File /mnt/Disk2/downloaded_models/7fb97ec39c0549e88fbd309c6808e564.zip already exists
# File /mnt/Disk2/downloaded_models/7006cdd8609a4a9282fb5325a2a38c03.zip already exists
# File /mnt/Disk2/downloaded_models/1059e7b781c14e83a6aaf83312c478bd.zip already exists
# File /mnt/Disk2/downloaded_models/5776244620f14d8fa923b96a8cfc4484.zip already exists
# File /mnt/Disk2/downloaded_models/043a29843dc0421d90eaba9332764c1d.zip already exists
# File /mnt/Disk2/downloaded_models/2315765e36ff49ff88d63abe03610c7f.zip already exists
# File /mnt/Disk2/downloaded_models/591a76b35b094562b9dec8ffa5b77387.zip already exists
# File /mnt/Disk2/downloaded_models/dfaa706052f34a089bdc4bf5f0d3f43c.zip already exists
# File /mnt/Disk2/downloaded_models/de132c5043d74403bc4654d72ac04f0b.zip already exists
# File /mnt/Disk2/downloaded_models/dc95731cdfee4b3e9d19a647ffd4ed58.zip already exists
# File /mnt/Disk2/downloaded_models/1f180101e4b542e4957a3c32c46680bc.zip already exists
# File /mnt/Disk2/downloaded_models/28e04e95351c44d0a61a0340fe2364ae.zip already exists
# File /mnt/Disk2/downloaded_models/1b2f5353c6fa48609747059f7360470f.zip already exists
# File /mnt/Disk2/downloaded_models/81a7f77e245048f89f0eff3883f097c5.zip already exists
# File /mnt/Disk2/downloaded_models/574c2893df004b27a9ef344049a2ca4f.zip already exists
# File /mnt/Disk2/downloaded_models/76d7c3492b0f436cae3f0de9996b58aa.zip already exists
# File /mnt/Disk2/downloaded_models/b47b0158ae6c4512b4159d892a65d81f.zip already exists
# File /mnt/Disk2/downloaded_models/a391b891ab5b4d00a137e12d6000fe0f.zip already exists
# File /mnt/Disk2/downloaded_models/c466075e60544f7dbbe783ed21b5c79d.zip already exists
# File /mnt/Disk2/downloaded_models/5181197cdcea4f69b919865aca3d3fbc.zip already exists
# File /mnt/Disk2/downloaded_models/b390bab15ff94759a9af7b30eb036ccd.zip already exists
# File /mnt/Disk2/downloaded_models/432e8c98f5ca4d9a93294e47322d6b4f.zip already exists
# File /mnt/Disk2/downloaded_models/49bdab1714c7405591df9c47aca92cba.zip already exists
# File /mnt/Disk2/downloaded_models/7e50bd45750b4b64bf22552914935acf.zip already exists
# File /mnt/Disk2/downloaded_models/637ccd0020b3493b94f9efdef354bc34.zip already exists
# File /mnt/Disk2/downloaded_models/e32e8129f48e4547b8bc988fdec22323.zip already exists
# File /mnt/Disk2/downloaded_models/881e556f0fd040e89af0ddce29010029.zip already exists
# File /mnt/Disk2/downloaded_models/79517e72e5a049638deffbc98f3d99ed.zip already exists
# File /mnt/Disk2/downloaded_models/e3f1f19053be4485acaf59e4eb52b83e.zip already exists
# File /mnt/Disk2/downloaded_models/d258b1f1872d4a229b0f5e556b0677d9.zip already exists
# File /mnt/Disk2/downloaded_models/5ad12c25507246fe9c717dc44e7a0f17.zip already exists
# File /mnt/Disk2/downloaded_models/e836bfa3baeb4aeea792019ce0e6d97e.zip already exists
# File /mnt/Disk2/downloaded_models/830ce6dd40064364b86d27cc4b89b1b2.zip already exists
# File /mnt/Disk2/downloaded_models/2b8ff29d76c345e2a574a76496921047.zip already exists
# File /mnt/Disk2/downloaded_models/9f9f1f30e04a43c08e19bf2fb357928b.zip already exists
# File /mnt/Disk2/downloaded_models/b81da2f13cc74334bb571c471a15c50a.zip already exists
# File /mnt/Disk2/downloaded_models/7e4deaf733de47279487e3519dcb39ad.zip already exists
# File /mnt/Disk2/downloaded_models/1a77cb11bd7249b7ae1f063dce247c2f.zip already exists
# File /mnt/Disk2/downloaded_models/dba61d5259204d6dabd5455ba22a9f86.zip already exists
# File /mnt/Disk2/downloaded_models/154a6d5a1c004489ab92ffb5bcf86f46.zip already exists
# File /mnt/Disk2/downloaded_models/9e4c73d924914de9a46e6a08aa8eabb4.zip already exists
# File /mnt/Disk2/downloaded_models/22adead908904b1da3dd998a8741be05.zip already exists
# File /mnt/Disk2/downloaded_models/ca968186ebb1429293b084fb04e0b5c6.zip already exists
# File /mnt/Disk2/downloaded_models/c948b05a704647b692749baebf11710d.zip already exists
# File /mnt/Disk2/downloaded_models/8d9ccb5816ea45cda29b7292430de834.zip already exists
# File /mnt/Disk2/downloaded_models/c4541cdfbb4a4d1a91d7f3b6a95d7a41.zip already exists
# File /mnt/Disk2/downloaded_models/a36c004ea55d420395e2952ccd01deaa.zip already exists
# File /mnt/Disk2/downloaded_models/646343f5c77940638a67484d023e6854.zip already exists
# File /mnt/Disk2/downloaded_models/25b3a8e5ed17496fafe617a35facb2d1.zip already exists
# File /mnt/Disk2/downloaded_models/a1d5b46e004e4a0cadc3cd628f7cc2e9.zip already exists
# File /mnt/Disk2/downloaded_models/0d05190ca8a147eeabca496d708f86c1.zip already exists
# File /mnt/Disk2/downloaded_models/f200da8b97f7416db524e88c6a9e3225.zip already exists
# File /mnt/Disk2/downloaded_models/47f770f7bad94bcb9eb923b849b3eb07.zip already exists
# File /mnt/Disk2/downloaded_models/4bed07d2e6e941a291adf01cfd4bd492.zip already exists
# File /mnt/Disk2/downloaded_models/3db4ac2a2f7a4e9795bafb410efc5b7e.zip already exists
# File /mnt/Disk2/downloaded_models/958975e0374b4344ae5d3f91a4b67fba.zip already exists
# File /mnt/Disk2/downloaded_models/7f8004fe5bf2480e836011ba70d2c423.zip already exists
# File /mnt/Disk2/downloaded_models/17233066be654ed689f3443154141374.zip already exists
# File /mnt/Disk2/downloaded_models/782cee3d2f824d2b925538b5d67778b5.zip already exists
# File /mnt/Disk2/downloaded_models/2fc0dedd62264f7780668da2490469d6.zip already exists
# File /mnt/Disk2/downloaded_models/33dda0d266df43f98145f728f6f49291.zip already exists
# File /mnt/Disk2/downloaded_models/12523f8dde5e47cd9ed49d2900d35dc8.zip already exists
# File /mnt/Disk2/downloaded_models/145b3c837f8e4787a35c822dcf9b82b7.zip already exists
# File /mnt/Disk2/downloaded_models/eb65dc8b40bf4b88bb71bb95b18a80e6.zip already exists
# File /mnt/Disk2/downloaded_models/5cd618ce407d4752bb755c53b8f86f9a.zip already exists
# File /mnt/Disk2/downloaded_models/d6fcfa410dfe402ba412cc7abe756cfd.zip already exists
# File /mnt/Disk2/downloaded_models/821f57d137454002bc0211d5ee58b6b1.zip already exists
# File /mnt/Disk2/downloaded_models/156364b54cfb45a58b88431b6c8ee6bc.zip already exists
# File /mnt/Disk2/downloaded_models/b9055360cf9a486a8e320ef66e58b811.zip already exists
# File /mnt/Disk2/downloaded_models/406e976873e14059bba1a7e77254d22d.zip already exists
# File /mnt/Disk2/downloaded_models/fe6a6e9cf17545179f8c6b81e5499b46.zip already exists
# File /mnt/Disk2/downloaded_models/2a145b57f3b84f75b87d210296aa9726.zip already exists
# File /mnt/Disk2/downloaded_models/25534804aaef429d9430851b709ca289.zip already exists
# File /mnt/Disk2/downloaded_models/a5b29a29005041dca3d8bfbc8c57c7e2.zip already exists
# File /mnt/Disk2/downloaded_models/4c73be3c326942b1a7fc5125f6fcfa8e.zip already exists
# File /mnt/Disk2/downloaded_models/6be4516021f145eeb197233794449cbf.zip already exists
# File /mnt/Disk2/downloaded_models/c65d2e46bea1435e9f181c355cb75308.zip already exists
# File /mnt/Disk2/downloaded_models/f7615bf3f44d4347bdc318d45b1bba60.zip already exists
# File /mnt/Disk2/downloaded_models/49a289b32d064196968c61ec07e1f81a.zip already exists
# File /mnt/Disk2/downloaded_models/374b709839644bc382418583b0dd906b.zip already exists
# File /mnt/Disk2/downloaded_models/4b6901b1357f4d7ba4801a15552cdc38.zip already exists
# File /mnt/Disk2/downloaded_models/2cf8ef623f0147949971e7fde49197cf.zip already exists
# File /mnt/Disk2/downloaded_models/a8105f496819446d999a466a274f960f.zip already exists
# File /mnt/Disk2/downloaded_models/3a7344b6c96740248844b150f2b6f9dc.zip already exists
# File /mnt/Disk2/downloaded_models/40d9ba7347e542d192077ea13301025b.zip already exists
# File /mnt/Disk2/downloaded_models/e0d6a27616724ff08604da137390e853.zip already exists
# File /mnt/Disk2/downloaded_models/72e529836ebb4ec7b499993c12ad4858.zip already exists
# File /mnt/Disk2/downloaded_models/6724e5968894459286a18f6d9caedde4.zip already exists
# File /mnt/Disk2/downloaded_models/68ac656b32564697b536d3fe75f68357.zip already exists
# Downloading model fd77d71d43da4f05b7d9adb5672b0481 (243/970)
# Downloading model e158531b92114958be372dd4bae6f772 (244/970)
# Downloading model 621be7f4eeeb4bcdabc8ecccdc8f0ee4 (245/970)
# Downloading model 8bd34787c6794d798812e6cba67615ea (246/970)
# Downloading model cf2510e1aa50468a81e3b19bb28f113c (247/970)
# Downloading model 5e7ffbf292df4cbe9c6213db6ce8d7b6 (248/970)
# Downloading model 1676d953ab8f44fc9af723d8e9258ee1 (249/970)
# Downloading model 21480103f9f44a52a5ee8bc37fb70bab (250/970)
# Downloading model 7a48fdd607cb48f79ddd815f5c0ac895 (251/970)
# Downloading model 339b42b5fe684ef9983434c5a18861f9 (252/970)
# Downloading model 8b9e41ca7a11402782b74f25b4377fa4 (253/970)
# Downloading model 1d24816602d943d1ae46f8df0bce9f48 (254/970)
# Downloading model 45bb173c0384450487421b687bf3bf5b (255/970)
# Downloading model ce3d838a80b54c1d901c47f23acbbbbe (256/970)
# Downloading model 18336f26bae84113ba32d714a91a464b (257/970)
# Downloading model 247427e297e94543a85e1362e6f3ddd8 (258/970)
# Downloading model 8ad89c53dc9842bfa7f623da25a770ae (259/970)
# Downloading model de0270387cd644379ca44aaea41bdb48 (260/970)
# Downloading model 01e66f0d11bb481b8197a928e220821a (261/970)
# Downloading model 68bce8b71469439790e77d1e109c84cc (262/970)
# Downloading model a0f40e7cb60b476c95f11205ba844eb6 (263/970)
# Downloading model 26e7425e03824753809f9a08c9fce951 (264/970)
# Downloading model 776d9405f4a14b0a985702822bd03aac (265/970)
# Downloading model e776cc1b82d54420a55e924510c027c5 (266/970)
# Downloading model 85785f16eb9948a98b9e0873dc4019cc (267/970)
# Downloading model 43832692129a43ba9c5501cf627de61e (268/970)
# Downloading model 3acece88030a43b8bc4a0adfa051c658 (269/970)
# Downloading model e194baf2a9e74ce5bcd212a6ac82aa76 (270/970)
# Downloading model 9a496608639b47fba3bf87f3a1eb75b0 (271/970)
# Downloading model 469ae12854c74a2399f5a45aa87a303b (272/970)
# Downloading model 8b5ebcb4bf90407d9d0ad9024488e5ae (273/970)
# Downloading model 2e42a108cee14fbfbda4e927f240ce5d (274/970)
# Downloading model ca2e1f81145d4e7aa46c2d301b602b75 (275/970)
# Downloading model 9bcaaf3eb5c948deb8b91a281ea4fa38 (276/970)
# Downloading model f56b16da42da49de8077499849c323c2 (277/970)
# Downloading model 6aa09226007e492c9c2df52ac928c075 (278/970)
# Downloading model 56dccb62700a4c04b42646e060c087f5 (279/970)
# Downloading model 7275b87bbc39419a94d6f9e70d9aa230 (280/970)
# Downloading model d55d89f11cf246acb28b671407c816cf (281/970)
# Downloading model 4fc93b071fba4682991ef64b9c31a13a (282/970)
# Downloading model 9546d0e5a2e14add87812f69aa3ad233 (283/970)
# Downloading model 1b1519d76bef48bbb8dc34de9c6188ff (284/970)
# Download failed for 3D-model: 1b1519d76bef48bbb8dc34de9c6188ff

# %% [markdown]
# ## Pre-processing 3D-models
#
# The files containing the 3D-models have to be unzipped to a temporary folder. 3D-Models provided by the API are in Graphics Language Transmission Format (glTF). I implemented a reader for this kind of files using the open source [pygltflib library](https://pypi.org/project/pygltflib/). This library is __not included in the course environment, but can be installed using pip__.
#
# <img src="fig/point_cloud_texture.png">
#
# _Figure 3: A Greek jug (A), its 3D point cloud (B), its texture image (C)._
#
# After extracting the texture and the point cloud data from each 3D-model,
# * I downsampled texture data to the size expected by the data extraction model, i.e. 299x299 pixels RGB, and I applied standardization to the texture images.
# * I downsampled point cloud data so that the number of vertices is the number computed in the EDA in notebook 1, i.e. 37838 vertices.
#
# I saved the downsampled data of each 3D-model in an .npz file containing "point cloud" data, and a second .npz file for texture images (fig. 3). The classifiers I implemented use either point cloud or texture data for input, so organizing these data separately at this stage will be beneficial later on.

# %% [markdown]
# ### Implement a function to decode GLTF files

# %%
import zipfile
from pygltflib import GLTF2, BufferFormat
import struct
import numpy as np
import warnings
warnings.filterwarnings("ignore") # the gltf loader raises some unecessary warning

DOWNLOAD_DIR = '/mnt/Disk2/downloaded_models' # Folder where the downloaded files are stored
TEMP_DIR = '/mnt/Disk2/temp' # Folder to temporarily extract the zipped files

def extract_gltf(model_uid):
    """
    Extracts the point cloud data from a gltf file as a numpy array.
    The returned array contains the 3D coordinates of all points in the point cloud.
    @param model_uid, string, id of a model
    @returns a numpy array of 3D coordinates
    """
    try:
        # create a temporary folder to extract this file
        unzip_dir = os.path.join(TEMP_DIR, model_uid)
        os.mkdir(unzip_dir)

        # unzip the downloaded 3D-model
        filename_zipped = os.path.join(DOWNLOAD_DIR, '{}.zip'.format(model_uid)) # zip file containing the the 3D-model
        with zipfile.ZipFile(filename_zipped, 'r') as zip_file:
            zip_file.extractall(unzip_dir)

        # After unzipping the file, open its "scene" data
        filename = os.path.join(unzip_dir, 'scene.gltf') # the "scene" file is always called scene.gltf
        gltf = GLTF2().load(filename)
        # load the binary data contained in the "scene.bin" into the gltf object
        gltf.convert_buffers(BufferFormat.DATAURI)

        # get the vertices for each primitive in each mesh
        vertices = []
        for mesh in gltf.meshes:
            for primitive in mesh.primitives:

                # get the binary data for this mesh primitive from the buffer
                accessor = gltf.accessors[primitive.attributes.POSITION]
                bufferView = gltf.bufferViews[accessor.bufferView]
                buffer = gltf.buffers[bufferView.buffer]
                data = gltf.decode_data_uri(buffer.uri)

                # pull each vertex from the binary buffer and convert it into a tuple of python floats
                for i in range(accessor.count):
                    index = bufferView.byteOffset + accessor.byteOffset + i*12  # the location in the buffer of this vertex
                    d = data[index:index+12]  # the vertex data
                    v = struct.unpack("<fff", d)   # convert from base64 to three floats
                    vertices.append(v)

        # convert the vertices to a numpy array
        vertices_np = np.array(vertices)
        return vertices_np
    
    finally:
        # whatever happens, delete the temporary folder
        os.remove(os.path.join(unzip_dir, 'scene.gltf'))
        os.remove(os.path.join(unzip_dir, 'scene.bin'))
        os.rmdir(unzip_dir)

# %% [markdown]
# ### Subsample point clouds
# 3D-models with a large number of vertices (up to several million) have a blotched appearance when rendered. Reducing the number of vertices brings up more detail (notebook 1, fig. 6) and increases processing speed. I subsampled the vertices in each 3D-model to the minimum number of vertices in the dataset prepared in notebook 1.

# %%
MAX_VERTICES = metadata_df['vertexCount'].min() # the lowest vertex count of any model in the dataset
print('The 3D-models will be downsampled to {} vertices.'.format(MAX_VERTICES))

def subsample_model(vertices_np):
    """
    Reduces the number of vertices in the 3D-model.
    @param vertices_np np array as returned by extract_gltf()
    @returns np array with MAX_VERTICES vertices
    """
    return pd.DataFrame(vertices_np).sample(n=MAX_VERTICES, random_state=0).to_numpy()
# Out:
# The 3D-models will be downsampled to 37838 vertices.

# %%
# get a list of all 3D-models that have been downloaded
downloaded_uid = [model_uid for model_uid in metadata_df['id'] if os.path.isfile(os.path.join(DOWNLOAD_DIR, '{}.zip'.format(model_uid)))]

# read the point cloud and subsample the vertices to MAX_VERTICES
vertices = []
for model_uid in downloaded_uid:
    vertices_np = extract_gltf(model_uid)
    vertices_np = subsample_model(vertices_np)
    vertices.append(vertices_np)

# %% [markdown]
# ### Rotate point clouds
# Generally, the scanning device's origin position is located above the object. Therefore, the 3D-model has to be rotated 90° clockwise in order to show  the object from the side ("elevation view").
# During mass digitization, objects are placed on a conveyor belt and moved under the 3D scanning device (notebook 1, fig. 1). Therefore, objects have to be placed in a stable balanced position. Sometimes this means placing the object facing down on the belt, therefore some objects have to be rotated 90° anti-clockwise. Additionally, some objects, particularly the broken ones, require a custom rotation. I examined each object individually and stored the required rotation in the file `data/rotation.csv`.

# %%
import pandas as pd
from scipy.spatial.transform import Rotation as R
from scipy.spatial.distance import cdist

def rotate(point_cloud, rotation):
    """
    Rotates 3D model.
    @param point_cloud a numpy array of vertex coordinates
    @rotation a list of x,y,z angles in degrees
    """
    r = R.from_euler('xyz', rotation, degrees=True)
    point_cloud = r.apply(point_cloud)
    return point_cloud

# read rotations file
rotation_df = pd.read_csv(os.path.join('data', 'rotation.csv'), index_col=False)
elevation_view = [] # array of rotated point clouds
for i in range(len(downloaded_uid)): # loop through downloaded files
    # apply the rotation 
    rotation = list(rotation_df.loc[i, ['x', 'y', 'z']])
    elevation_view.append(rotate(vertices[i], rotation))

# %% [markdown]
# ## Generate views
# A 3D-model cannot be represented by a single 2D view. Therefore, following archaeological practice, each object will be represented by an elevation view (from the side), a plan view (from the top) and a cross-section.
# * the elevation view (side) was already generated during te previous step
# * the plan view (top) is generated by rotating the object 90° degrees
# * the cross-section view shows the points closer to a vertical plane passing through the middle of the object

# %%
# make plan views
plan_view = []
rotation = [90, 0, 0] # rotate elevation view into plan view
for i in range(len(downloaded_uid)): # loop through downloaded files
    plan_view.append(rotate(elevation_view[i], rotation))
    
# make cross-sections
section_view = []
for i in range(len(downloaded_uid)): # loop through downloaded files
    z_coords = [item[2] for item in elevation_view[i]] # the z-coords of all vertices
    z_span = np.max(z_coords) - np.min(z_coords) # the z span ("depth")
    z_mean = np.mean(z_coords) #  the z coord of the middle
    # should yield +- 10% of vertices closest to middle vertical plane
    section_vertices = np.array([item for item in elevation_view[i] if abs(item[2] - z_mean) < z_span/20]) 
    section_view.append(section_vertices)

# %% [markdown]
# ## Render the views
# The views (elevation, top and cross-section) have to be rendered to images to use as input for the classifier. The image data has to be of the required size and type. As explained in the project proposal, [Inception v3](https://tfhub.dev/google/imagenet/inception_v3/feature_vector/1) will be used. The Tensor Flow documentation states that the [common input format for image-related tasks](https://www.tensorflow.org/hub/common_signatures/images) requires image batches of 299x299 elements of type float32, with 3 color channels, where color values are normalized to [0,1]. However, as disk space is critical, I stored the data as arrays of uint8 (range 0 - 255), containing only one color channel.

# %%
import numpy as np

import matplotlib.pyplot as plt
from matplotlib.figure import Figure
from matplotlib.backends.backend_agg import FigureCanvas
from PIL import Image

def plot_model(ax, point_cloud, aspect_ratio, title=None):
    """
    Plots a point cloud in orthogonal projection (i.e. without perspective), onto a pyplot figure axis.
    @param ax matplotlib axis
    @param point_cloud np array of vertices (x,y,z) coordinates of the input data
    @param aspect_ratio float aspect ratio of the input data
    @param string title, e.g. model identifier
    """
    ax.set_aspect(aspect_ratio)
    ax.scatter(point_cloud[:,0], point_cloud[:,1], s=1, color='black') # plot the x/y coordinates of each vertex
    if title:
        ax.set_title(title)
    ax.axis("off") # don't show axis labels and ticks

def point_cloud_to_array(point_cloud, aspect_ratio, size):
    """
    Plots a np array of point cloud 3D coordinates onto a "hidden" canvas, returns a flat np array of grayscale values.
    @param point_cloud np array of vertices (x,y,z) coordinates of the input data
    @param aspect_ratio float aspect ratio of the input data
    @param size int width and height in pixels of the output image
    @returns flattened np array of grayscale values
    """
    CANVAS_SIZE = 20 # make the canvas larger than the expected output. 20x20 inches is arbitrary, but canvas should be square, as is the output image.
    
    # Create a "hidden" canvas
    ax = Figure(figsize=(CANVAS_SIZE,CANVAS_SIZE)).subplots()
    canvas = FigureCanvas(ax.get_figure())

    # plot the vertices onto "hidden" canvas
    plot_model(ax, point_cloud, aspect_ratio)
    canvas.draw()

    # resize to image size expected by TF model
    img = Image.frombytes('RGB', canvas.get_width_height(),canvas.tostring_rgb()) # convert canvas to PIL Image
    img = img.resize((size,size), Image.BILINEAR)
    
    return(np.array(img)[:,:,0].flatten()) # flat np array of first channel only, as rendered in black by plot_model()

# %%
# width and height of the image, as expected by the TF model, in pixels
TF_SIZE = 299

# Render elevation views
rendered_elevation = []
for idx in range(len(elevation_view)):
    # plot elevation view
    point_cloud = elevation_view[idx] # a numpy array of 3D coordinates
    # compute the aspect ratio of the input data
    # the input data have been rotated, so the plot shows x/z axes
    dx = max(point_cloud[:,0]) - min(point_cloud[:,0])
    dz = max(point_cloud[:,2]) - min(point_cloud[:,2])
    aspect_ratio = dz/dx
    # Render input data to size expected by TF model, as a flat np array of grayscale values
    X = point_cloud_to_array(point_cloud, aspect_ratio, TF_SIZE) 
    rendered_elevation.append(X)

# Render plan views
rendered_plan = []
for idx in range(len(plan_view)):
    point_cloud = plan_view[idx] # a numpy array of 3D coordinates
    # compute the aspect ratio of image
    # images have been rotated, so the plot shows x/y axes
    dx = max(point_cloud[:,0]) - min(point_cloud[:,0])
    dy = max(point_cloud[:,1]) - min(point_cloud[:,1])
    aspect_ratio = dy/dx
    # Render input data to size expected by TF model, as a flat np array of grayscale values
    X = point_cloud_to_array(point_cloud, aspect_ratio, TF_SIZE) 
    rendered_plan.append(X)

# Render cross-sections
rendered_section = []
for idx in range(len(section_view)):
    # use the elevation view to compute the aspect ratio (not the section view!)
    point_cloud = elevation_view[idx] 
    dx = max(point_cloud[:,0]) - min(point_cloud[:,0])
    dz = max(point_cloud[:,2]) - min(point_cloud[:,2])
    aspect_ratio = dz/dx
    point_cloud = section_view[idx] # a numpy array of 3D coordinates
    # Render input data to size expected by TF model, as a flat np array of grayscale values
    X = point_cloud_to_array(point_cloud, aspect_ratio, TF_SIZE) 
    rendered_section.append(X)

# %% [markdown]
# ### Plot some models at random
# To check if the previous steps worked well, plot the elevation, plan and section views of randomly selected models. The model's identifier is shown at the bottom.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import random 

# select some 3D-models at random
num_models = 4
fig, ax = plt.subplots(3, num_models, figsize=(20, 10))

for i in range(num_models):
    # select random 3D-model
    idx = random.randrange(len(vertices))
    # elevation views
    ax[0, i].imshow(rendered_elevation[idx].reshape(299, 299), cmap=plt.cm.gray)
    ax[0, i].axis('off')
    # plan views
    ax[1, i].imshow(rendered_plan[idx].reshape(299, 299), cmap=plt.cm.gray)
    ax[1, i].axis('off')
    # section views
    ax[2, i].imshow(rendered_section[idx].reshape(299, 299), cmap=plt.cm.gray)
    ax[2, i].axis('off')
    # show 3D-model id
    model_uid = downloaded_uid[idx] #  a string identifying the model
    ax[2, i].set_title(model_uid, y=0)
plt.tight_layout()
fig.suptitle('Example 3D-models', fontsize=14)
plt.show();

# %% [markdown]
# ## Save
# The rendered models can now be saved to a compressed npz file.

# %%
# The npz file with all the models is too large for Github file size limit
NPZ_DIR = '/mnt/Disk2/npz_models' # Folder to store the 3D-models files

# save rendered views to compressed file
np.savez_compressed(os.path.join(NPZ_DIR, 'point_clouds.npz'),
         model_uid = downloaded_uid,
         elevation = rendered_elevation,
         plan = rendered_plan,
         section = rendered_section
        )

# %% [markdown]
# ## test

# %%
i = 284
rotation = [-90, 0, 0]
model_uid = downloaded_uid[i]
fig, ax = plt.subplots(1, 1, figsize=(10, 10))
point_cloud = rotate(vertices[i], rotation)
dx = max(point_cloud[:,0]) - min(point_cloud[:,0])
dz = max(point_cloud[:,2]) - min(point_cloud[:,2])
aspect_ratio = dz/dx
plot_model(point_cloud, model_uid, ax, aspect_ratio)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-129-1b30a1e3fe9c> in <module>
#       1 i = 284
#       2 rotation = [-90, 0, 0]
# ----> 3 model_uid = downloaded_uid[i]
#       4 fig, ax = plt.subplots(1, 1, figsize=(10, 10))
#       5 point_cloud = rotate(vertices[i], rotation)
#
# IndexError: list index out of range
